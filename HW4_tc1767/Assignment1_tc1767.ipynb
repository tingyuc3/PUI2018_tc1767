# %%
from __future__ import print_function
__author__= 'tyc'

import pylab as pl
# this package sets up pretty plots
import seaborn
from scipy.optimize import curve_fit, minimize
import numpy as np
random.seed(2)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mymean = 100

# %%
df = mymean

# %%
mysize = (2000 / (np.random.randint(1,high=200,size=100))).astype(int)
print(mysize)
# Out:
# [ 11 125  27  86  45  26  19 250  12  11  20  26  41  31  62  13  16  17
#   52  11  10  19 400  11  18  38  19  51  58  33  16  29  28  22  10  42
#   10  20  16  62  10  24  37  39  15  31  40  50  11  14  11 125  14  13
#   13  16  27  10  18  18  10  23  20  45  60  74  14  25  14  48  57  32
#   14  28  22  10 100  35  15  28  11  24  32  10  15  20  13  22  13  45
#   37 117  35  16  13  45  11  28  12  33]

# %% [markdown]
# # Chi squared Distribution

# %%
import numpy as np
md = {}
md['chisq'] = np.random.chisquare(df, size=100)
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('Chi squared Distribution')

# %% [markdown]
# ### Figure 1.1: Chi sq distribution: df = 100, N=100

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 99.61, standard deviation: 13.52

# %%
md['chisq'] = {} 
for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
md['chisq']['means'] = {}
axchisq_mu_n = pl.figure().add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure1.2: For chi squared distribution, as the same size gets larger, the sample mean tends to get closer to the expected mean which corresponds to the law of large number.

# %% [markdown]
# # Normal Distribution

# %%
md['gaus'] = np.random.normal(df,1,100)
pl.hist(md['gaus'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('Normal Distribution')

# %% [markdown]
# ### Figure2.1: Normal distribution: $\mu$ = 100, $\sigma$ = 1, N=100

# %%
print ("Normal mean: %.2f, standard deviation: %.2f"%(md['gaus'].mean(), md['gaus'].std()))
# Out:
# Normal mean: 100.04, standard deviation: 1.01

# %%
md['gaus'] = {}
for n in mysize:
    md['gaus'][n] = np.random.normal(100,1,n)
md['gaus']['means'] = {}
axgaus_mu_n = pl.figure().add_subplot(111)

for nn in md['gaus']:
    if not type(nn) == str:
        md['gaus']['means'][nn] = md['gaus'][nn].mean()
        axgaus_mu_n.plot(nn, md['gaus']['means'][nn], 'o')
        axgaus_mu_n.set_xlabel('sample size', fontsize=18)
        axgaus_mu_n.set_ylabel('sample mean', fontsize=18)
        axgaus_mu_n.set_title('Normal', fontsize=18)
        axgaus_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure 2.2: For Normal distribution, as the same size gets larger, the sample mean tends to get closer to the expected mean which corresponds to the law of large number.

# %% [markdown]
# # Poisson Distribution

# %%
md['pois'] = np.random.poisson(df,100)
pl.hist(md['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('Poisson Distribution')

# %% [markdown]
# ### Figure3.1: Poisson distribution: df = 100, N=100

# %%
print ("Poisson mean: %.2f, standard deviation: %.2f"%(md['pois'].mean(), md['pois'].std()))
# Out:
# Poisson mean: 100.00, standard deviation: 9.76

# %%
md['pois'] = {}
for n in mysize:
    md['pois'][n] = np.random.poisson(df,n)
md['pois']['means'] = {}
axpois_mu_n = pl.figure().add_subplot(111)

for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()
        axpois_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axpois_mu_n.set_xlabel('sample size', fontsize=18)
        axpois_mu_n.set_ylabel('sample mean', fontsize=18)
        axpois_mu_n.set_title('Poisson', fontsize=18)
        axpois_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure3.2: For Poisson distribution, as the same size gets larger, the sample mean tends to get closer to the expected mean which corresponds to the law of large number.

# %% [markdown]
# # Binomial Distribution

# %%
md['binomial'] = np.random.binomial(df*2,0.5,100)
pl.hist(md['binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('Binomial Distribution')

# %% [markdown]
# ### Figure 4.1: Binomial distribution: n = 200, p = 0.5, N=100

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(md['binomial'].mean(), md['binomial'].std()))
# Out:
# Binomial mean: 99.79, standard deviation: 6.68

# %%
md['binomial'] = {}
for n in mysize:
    md['binomial'][n] = np.random.binomial(df*2,0.5,n)
md['binomial']['means'] = {}
axbinom_mu_n = pl.figure().add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        axbinom_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axbinom_mu_n.set_xlabel('sample size', fontsize=18)
        axbinom_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinom_mu_n.set_title('Binomial', fontsize=18)
        axbinom_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure4.2: For Binomial distribution, as the same size gets larger, the sample mean tends to get closer to the expected mean which corresponds to the law of large number.

# %% [markdown]
# # Logistic Distribution

# %%
md['logistic'] = np.random.logistic(df,1,100)
pl.hist(md['logistic'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('Logistic Distribution')

# %% [markdown]
# ### Figure5.1: Logistic distribution: $\mu$= 100, s=1, N=100

# %%
print ("Logistic mean: %.2f, standard deviation: %.2f"%(md['logistic'].mean(), md['logistic'].std()))
# Out:
# Logistic mean: 100.05, standard deviation: 1.98

# %%
md['logistic'] = {}
for n in mysize:
    md['logistic'][n] = np.random.logistic(df,1,n)
md['logistic']['means'] = {}
axlogistic_mu_n = pl.figure().add_subplot(111)

for nn in md['logistic']:
    if not type(nn) == str:
        md['logistic']['means'][nn] = md['logistic'][nn].mean()
        axlogistic_mu_n.plot(nn, md['logistic']['means'][nn], 'o')
        axlogistic_mu_n.set_xlabel('sample size', fontsize=18)
        axlogistic_mu_n.set_ylabel('sample mean', fontsize=18)
        axlogistic_mu_n.set_title('Logistic', fontsize=18)
        axlogistic_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')

# %% [markdown]
# ### Figure5.2: For logistic distribution, as the same size gets larger, the sample mean tends to get closer to the expected mean which corresponds to the law of large number.

# %%
allmeans = list(md['gaus']['means'].values())
allmeans.extend(md['chisq']['means'].values())
allmeans.extend(md['pois']['means'].values())
allmeans.extend(md['binomial']['means'].values())
allmeans.extend(md['logistic']['means'].values())
pl.figure()
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title('Logistic',fontsize = 18)
