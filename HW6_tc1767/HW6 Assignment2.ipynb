# %% [markdown]
# # SQL CARTO QUERY FUNCTION
# # written for PUI2016_Python2

# %% [markdown]
# ##### This notebook is set up to link as a default to the fb55 account.  To turn in the homework use the citibike dataset - check that you are able to read in about 40k rows

# %%
SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q='

import urllib2
import urllib
import StringIO
import ast
import pandas as pd

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urllib.urlencode({'format': format, 'q': query})
    try:
        response = urllib2.urlopen(source, data)
    except urllib2.HTTPError, e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

# %%
try:
    import urllib2 as ulib
except ImportError:
    import urllib3 as ulib

try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import ast
import pandas as pd

# %%
def queryCartoDB(query, formatting = 'CSV', source = SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    
    data = urlencode({'format': formatting, 'q': query}).encode("utf-8")
    try:
        response = urlopen(source, data)
        return response.read()
    except HTTPError as e:
        raise (ValueError('\n'.join(ast.literal_eval(e.readline())['error'])))
        
def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %%
test = '''
SELECT *
FROM citibike;
'''

# %%
table = get_data(test)
table
# Out:
#        the_geom        start_station_name  the_geom_webmercator  field_1  \
# 0           NaN        E 20 St & Park Ave                   NaN      175
# 1           NaN          W 43 St & 10 Ave                   NaN     1159
# 2           NaN         E 6 St & Avenue B                   NaN     2827
# 3           NaN           E 12 St & 3 Ave                   NaN     4961
# 4           NaN           W 41 St & 8 Ave                   NaN     6156
# 5           NaN           5 Ave & E 29 St                   NaN     7433
# 6           NaN      Allen St & Hester St                   NaN     7779
# 7           NaN           E 39 St & 3 Ave                   NaN     8327
# 8           NaN          10 Ave & W 28 St                   NaN     9435
# 9           NaN            E 2 St & 2 Ave                   NaN    10472
# 10          NaN           1 Ave & E 44 St                   NaN    10931
# 11          NaN           W 45 St & 6 Ave                   NaN    11361
# ...

# %% [markdown]
# # Task 1 -  Familiarize with SQL Clauses

# %%
query = '''
SELECT * FROM citibike
WHERE tripduration <= 10800
ORDER BY start_station_id ASC, tripduration ASC
'''
table = get_data(query)
table.head(10)
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     9059
# 1       NaN   W 52 St & 11 Ave                   NaN    40772
# 2       NaN   W 52 St & 11 Ave                   NaN    40770
# 3       NaN   W 52 St & 11 Ave                   NaN    22002
# 4       NaN   W 52 St & 11 Ave                   NaN    43107
# 5       NaN   W 52 St & 11 Ave                   NaN    32603
# 6       NaN   W 52 St & 11 Ave                   NaN    16015
# 7       NaN   W 52 St & 11 Ave                   NaN    41366
# 8       NaN   W 52 St & 11 Ave                   NaN    42084
# 9       NaN   W 52 St & 11 Ave                   NaN     2348
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929           107  2015-02-03 10:10:00+00
# 1               -73.993929           189  2015-02-07 10:40:00+00
# 2               -73.993929           229  2015-02-07 10:40:00+00
# ...

# %%
table.tail(10)
# Out:
#        the_geom          start_station_name  the_geom_webmercator  field_1  \
# 46141       NaN  South End Ave & Liberty St                   NaN    17637
# 46142       NaN  South End Ave & Liberty St                   NaN     1297
# 46143       NaN  South End Ave & Liberty St                   NaN    11648
# 46144       NaN  South End Ave & Liberty St                   NaN    44708
# 46145       NaN  South End Ave & Liberty St                   NaN     6846
# 46146       NaN  South End Ave & Liberty St                   NaN    27243
# 46147       NaN  South End Ave & Liberty St                   NaN    10232
# 46148       NaN  South End Ave & Liberty St                   NaN    23568
# 46149       NaN  South End Ave & Liberty St                   NaN     8891
# 46150       NaN  South End Ave & Liberty St                   NaN     1576
#
#        start_station_longitude  tripduration               starttime  \
# 46141               -74.015756          1830  2015-02-04 16:33:00+00
# ...

# %%
query = '''
SELECT DISTINCT start_station_id FROM citibike
'''
table = get_data(query)
table
# Out:
#      start_station_id  Unnamed: 1
# 0                 120         NaN
# 1                 285         NaN
# 2                 251         NaN
# 3                 195         NaN
# 4                 453         NaN
# 5                 144         NaN
# 6                 266         NaN
# 7                 263         NaN
# 8                 216         NaN
# 9                 328         NaN
# 10                353         NaN
# 11                212         NaN
# 12                383         NaN
# 13                538         NaN
# 14                217         NaN
# 15                300         NaN
# 16                456         NaN
# 17                128         NaN
# 18                223         NaN
# 19                244         NaN
# 20                494         NaN
# 21                403         NaN
# 22                260         NaN
# 23                445         NaN
# 24                411         NaN
# 25                377         NaN
# ...

# %%
#COUNT THE NUMBER OF TRIPS
query = '''
SELECT COUNT(bikeid) FROM citibike
'''
table = get_data(query)
print(table)
# Out:
#    count  Unnamed: 1
# 0  46200         NaN

# %%
query = '''
SELECT MIN(tripduration) FROM citibike'''
table = get_data(query)
print(table)
# Out:
#    min  Unnamed: 1
# 0   60         NaN

# %%
query = '''
SELECT MAX(tripduration) FROM citibike'''
table = get_data(query)
print(table)
# Out:
#      max  Unnamed: 1
# 0  43016         NaN

# %%
query = '''
SELECT AVG(tripduration) FROM citibike'''
table = get_data(query)
print(table)
# Out:
#           avg  Unnamed: 1
# 0  675.865823         NaN

# %% [markdown]
# # Task 2 - Working with date/time

# %%
query = '''
SELECT * FROM citibike
WHERE EXTRACT(DAY FROM starttime::date) >= 2'''
table = get_data(query)
table
# Out:
#        the_geom        start_station_name  the_geom_webmercator  field_1  \
# 0           NaN           5 Ave & E 29 St                   NaN     7433
# 1           NaN      Allen St & Hester St                   NaN     7779
# 2           NaN           E 39 St & 3 Ave                   NaN     8327
# 3           NaN          10 Ave & W 28 St                   NaN     9435
# 4           NaN            E 2 St & 2 Ave                   NaN    10472
# 5           NaN           1 Ave & E 44 St                   NaN    10931
# 6           NaN           W 45 St & 6 Ave                   NaN    11361
# 7           NaN           W 18 St & 6 Ave                   NaN    12173
# 8           NaN           E 58 St & 3 Ave                   NaN    12211
# 9           NaN           E 33 St & 5 Ave                   NaN    12560
# 10          NaN           W 31 St & 7 Ave                   NaN    13239
# 11          NaN           5 Ave & E 29 St                   NaN    13365
# ...

# %%
query = '''
SELECT * FROM citibike
WHERE EXTRACT(DOW FROM cast(starttime as date)) in (6,0)'''
table = get_data(query)
table
# Out:
#        the_geom        start_station_name  the_geom_webmercator  field_1  \
# 0           NaN        E 20 St & Park Ave                   NaN      175
# 1           NaN          W 43 St & 10 Ave                   NaN     1159
# 2           NaN         E 6 St & Avenue B                   NaN     2827
# 3           NaN           E 12 St & 3 Ave                   NaN     4961
# 4           NaN           W 41 St & 8 Ave                   NaN     6156
# 5           NaN           E 20 St & 2 Ave                   NaN    39894
# 6           NaN        Broadway & W 60 St                   NaN    41512
# 7           NaN         E 6 St & Avenue D                   NaN    41595
# 8           NaN            Great Jones St                   NaN    41806
# 9           NaN           W 13 St & 6 Ave                   NaN    42316
# 10          NaN          W 34 St & 11 Ave                   NaN    42532
# 11          NaN           W 41 St & 8 Ave                   NaN    42915
# ...

# %%
query = '''
SELECT AVG(tripduration) FROM citibike
WHERE EXTRACT(DOW FROM cast(starttime as date)) in (6,0)
'''
table = get_data(query)
print(table)
# Out:
#           avg  Unnamed: 1
# 0  662.942181         NaN

# %%
query = '''
SELECT * FROM citibike
WHERE EXTRACT(DOW FROM cast(starttime as date)) in (1,2,3,4,5)'''
table = get_data(query)
table
# Out:
#        the_geom              start_station_name  the_geom_webmercator  \
# 0           NaN                 5 Ave & E 29 St                   NaN
# 1           NaN            Allen St & Hester St                   NaN
# 2           NaN                 E 39 St & 3 Ave                   NaN
# 3           NaN                10 Ave & W 28 St                   NaN
# 4           NaN                  E 2 St & 2 Ave                   NaN
# 5           NaN                 1 Ave & E 44 St                   NaN
# 6           NaN                 W 45 St & 6 Ave                   NaN
# 7           NaN                 W 18 St & 6 Ave                   NaN
# 8           NaN                 E 58 St & 3 Ave                   NaN
# 9           NaN                 E 33 St & 5 Ave                   NaN
# 10          NaN                 W 31 St & 7 Ave                   NaN
# 11          NaN                 5 Ave & E 29 St                   NaN
# ...

# %%
query = '''
SELECT AVG(tripduration) FROM citibike
WHERE EXTRACT(DOW FROM cast(starttime as date)) in (1,2,3,4,5)
'''
table = get_data(query)
print(table)
# Out:
#           avg  Unnamed: 1
# 0  681.052292         NaN

# %% [markdown]
# # Task 3 - Working with Space

# %%
query = '''
SELECT start_station_name FROM citibike
GROUP BY start_station_name'''
table = get_data(query)
table
# Out:
#                 start_station_name  Unnamed: 1
# 0             E 30 St & Park Ave S         NaN
# 1          Pearl St & Anchorage Pl         NaN
# 2                  W 56 St & 6 Ave         NaN
# 3                   West Thames St         NaN
# 4          Bank St & Washington St         NaN
# 5                  8 Ave & W 52 St         NaN
# 6               E 11 St & Broadway         NaN
# 7         DeKalb Ave & Skillman St         NaN
# 8    Atlantic Ave & Fort Greene Pl         NaN
# 9                Avenue D & E 8 St         NaN
# 10            S 3 St & Bedford Ave         NaN
# 11          W Broadway & Spring St         NaN
# 12                 2 Ave & E 31 St         NaN
# 13                 E 33 St & 5 Ave         NaN
# 14        MacDougal St & Prince St         NaN
# 15    Clermont Ave & Lafayette Ave         NaN
# 16          Barclay St & Church St         NaN
# 17          Forsyth St & Broome St         NaN
# 18                 W 13 St & 6 Ave         NaN
# ...

# %%
query = '''
SELECT start_station_name, COUNT(bikeid) FROM citibike
GROUP BY start_station_name
'''
table = get_data(query)
table
# Out:
#                 start_station_name  count
# 0             E 30 St & Park Ave S    227
# 1          Pearl St & Anchorage Pl     54
# 2                  W 56 St & 6 Ave    164
# 3                   West Thames St    107
# 4          Bank St & Washington St    125
# 5                  8 Ave & W 52 St    133
# 6               E 11 St & Broadway    115
# 7         DeKalb Ave & Skillman St     10
# 8    Atlantic Ave & Fort Greene Pl     36
# 9                Avenue D & E 8 St     38
# 10            S 3 St & Bedford Ave     13
# 11          W Broadway & Spring St    159
# 12                 2 Ave & E 31 St    302
# 13                 E 33 St & 5 Ave    213
# 14        MacDougal St & Prince St    247
# 15    Clermont Ave & Lafayette Ave     25
# 16          Barclay St & Church St    244
# 17          Forsyth St & Broome St    212
# 18                 W 13 St & 6 Ave    257
# 19                 W 17 St & 8 Ave    288
# 20              E 20 St & Park Ave    218
# ...

# %%
query = '''
SELECT start_station_name, COUNT(bikeid) FROM citibike
WHERE (SQRT(POWER((start_station_latitude - 40.7577) * 111000, 2) + POWER((start_station_longitude + 73.9857) * 111000, 2))) <= 500
GROUP BY start_station_name'''
table = get_data(query)
table
# Out:
#    start_station_name  count
# 0     W 45 St & 8 Ave    141
# 1  Broadway & W 49 St    213
# 2     W 43 St & 6 Ave    112
# 3     W 45 St & 6 Ave    141
# 4  Broadway & W 41 St    251

# %% [markdown]
# # Task 4 - Putting it all together

# %%
query = '''
SELECT start_station_name, AVG(tripduration) FROM citibike
WHERE EXTRACT(DOW FROM cast(starttime as date)) in (6,0)
AND (SQRT(POWER((start_station_latitude - 40.7577) * 111000, 2) + POWER((start_station_longitude + 73.9857) * 111000, 2))) <= 500
GROUP BY start_station_name
ORDER BY avg DESC
LIMIT 1'''
table = get_data(query)
table
# Out:
#    start_station_name          avg
# 0  Broadway & W 49 St  1010.104167

# %%
query = '''
SELECT start_station_name, end_station_name, COUNT(bikeid) FROM citibike
WHERE (SQRT(POWER((start_station_latitude - 40.7577) * 111000, 2) + POWER((start_station_longitude + 73.9857) * 111000, 2))) <= 500
AND tripduration < 7200
GROUP BY start_station_name, end_station_name
ORDER BY count
'''
table = get_data(query)
table
# Out:
#      start_station_name            end_station_name  count
# 0       W 45 St & 6 Ave     E 53 St & Lexington Ave      1
# 1       W 45 St & 6 Ave             E 25 St & 1 Ave      1
# 2    Broadway & W 41 St             E 10 St & 5 Ave      1
# 3       W 43 St & 6 Ave             E 39 St & 3 Ave      1
# 4       W 45 St & 8 Ave        E 30 St & Park Ave S      1
# 5    Broadway & W 49 St          Broadway & W 29 St      1
# 6       W 45 St & 6 Ave          Broadway & W 55 St      1
# 7    Broadway & W 41 St        Allen St & Hester St      1
# 8       W 45 St & 6 Ave             E 25 St & 2 Ave      1
# 9       W 45 St & 8 Ave             9 Ave & W 45 St      1
# 10      W 43 St & 6 Ave         FDR Drive & E 35 St      1
# 11   Broadway & W 41 St             9 Ave & W 45 St      1
# 12   Broadway & W 41 St           E 7 St & Avenue A      1
# 13   Broadway & W 49 St            W 56 St & 10 Ave      1
# 14   Broadway & W 41 St     Duane St & Greenwich St      1
# ...
